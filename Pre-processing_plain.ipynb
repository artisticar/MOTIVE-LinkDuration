# %%
import os
import pandas as pd
import numpy as np

print(os.getcwd())
PATH = os.getcwd()
PATH = PATH + "/data/"
# Out:
# /Users/JunxiChen/Documents/MOTIVE_LinkDuration

# %%
P1 = PATH + "newx2.csv"

df = pd.read_csv(P1, encoding='utf-8', engine='python')

# %%
print(df.shape)
print(df.columns)
# Out:
# (19754, 77)
# Index(['localx_X', 'localy_X', 'vel_X', 'acc_X', 'laneID_X', 'localx_Y',
#        'localy_Y', 'vel_Y', 'acc_Y', 'laneID_Y', 'relative_x', 'relative_y',
#        'relative_distance', 'num_lanes', 'duration', 'direction_X__1.0',
#        'direction_X__2.0', 'direction_X__3.0', 'direction_X__4.0',
#        'direction_Y__1.0', 'direction_Y__2.0', 'direction_Y__3.0',
#        'direction_Y__4.0', 'movement_X__1.0', 'movement_X__2.0',
#        'movement_X__3.0', 'movement_Y__1.0', 'movement_Y__2.0',
#        'movement_Y__3.0', 'exit_X__201.0', 'exit_X__203.0', 'exit_X__204.0',
#        'exit_X__205.0', 'exit_X__206.0', 'exit_X__207.0', 'exit_X__208.0',
#        'exit_X__209.0', 'exit_X__210.0', 'exit_X__211.0', 'exit_Y__201.0',
#        'exit_Y__203.0', 'exit_Y__204.0', 'exit_Y__205.0', 'exit_Y__206.0',
#        'exit_Y__207.0', 'exit_Y__208.0', 'exit_Y__209.0', 'exit_Y__210.0',
#        'exit_Y__211.0', 'int_X__0.0', 'int_X__1.0', 'int_X__2.0', 'int_X__3.0',
# ...

# %%
#dfr = pd.read_csv(P1, encoding='utf-8', engine='python')
#df_reverse.rename(columns = {'' : 'intruder', 'intruder' : 'agent_x'}, inplace='true')




dfr = df[['localx_Y','localy_Y', 'vel_Y', 'acc_Y', 'laneID_Y',
         'localx_X', 'localy_X', 'vel_X', 'acc_X', 'laneID_X',
         'relative_x', 'relative_y', 'relative_distance', 'num_lanes', 'duration',
          'direction_Y__1.0', 'direction_Y__2.0', 'direction_Y__3.0','direction_Y__4.0',
         'direction_X__1.0','direction_X__2.0', 'direction_X__3.0', 'direction_X__4.0',
         'movement_Y__1.0', 'movement_Y__2.0', 'movement_Y__3.0',
         'movement_X__1.0', 'movement_X__2.0','movement_X__3.0',
         'exit_Y__201.0',
        'exit_Y__203.0', 'exit_Y__204.0', 'exit_Y__205.0', 'exit_Y__206.0',
       'exit_Y__207.0', 'exit_Y__208.0', 'exit_Y__209.0', 'exit_Y__210.0',
       'exit_Y__211.0',
         'exit_X__201.0', 'exit_X__203.0', 'exit_X__204.0',
       'exit_X__205.0', 'exit_X__206.0', 'exit_X__207.0', 'exit_X__208.0',
       'exit_X__209.0', 'exit_X__210.0', 'exit_X__211.0',
          'int_Y__0.0', 'int_Y__1.0', 'int_Y__2.0', 'int_Y__3.0',
       'int_Y__4.0', 
          'int_X__0.0', 'int_X__1.0', 'int_X__2.0', 'int_X__3.0',
       'int_X__4.0',
         'section_Y__0.0', 'section_Y__1.0', 'section_Y__2.0', 'section_Y__3.0', 'section_Y__4.0',
       'section_Y__5.0',
          'section_X__0.0', 'section_X__1.0', 'section_X__2.0',
       'section_X__3.0', 'section_X__4.0', 'section_X__5.0',
          'distance_y_toexit', 'distance_x_toexit', 'range',
       'zero_to_10', 'ten_to_30', 'thirty_plus'
         ]]
print(dfr)

dfr.to_csv("try.csv")


#df_new = pd.concat([df, dfr], axis=0)



#print(df_new)
#df_new.to_csv("try.csv")
# Out:
#        localx_Y  localy_Y  vel_Y  acc_Y  laneID_Y  localx_X  localy_X  vel_X  \
# 0        23.303   387.964  38.27  -3.96         2    71.841   446.091   0.00
# 1        19.979   418.463  38.33   1.54         2    48.925   444.066   0.00
# 2        26.931   107.493  40.53  -0.79         3    18.327    40.530  38.59
# 3        42.084    31.120   0.00   0.00         1    49.855    60.078   6.47
# 4        71.841   446.091   0.00   0.00         2    37.330   356.416  50.18
# 5        48.925   444.066   0.00   0.00         0    35.364   373.326  40.84
# 6        30.712   134.419  33.50   8.77         3    53.448    55.936   9.59
# 7        71.841   446.091   0.00   0.00         2    40.472   308.769  50.17
# 8        40.711   313.515  45.97 -15.80         3    48.925   444.066   0.00
# 9        15.215    44.153  44.04   0.00         2    38.285   142.789  40.26
# 10       14.494   640.890  51.30   0.16         2   -41.556   797.838  51.71
# ...

# %%
dft = pd.read_csv(PATH + "try.csv")

print(dft)
df_new = pd.concat([df,dft],axis=0)
print(df_new)
df_new.to_csv("k.csv")
# Out:
#        localx_X  localy_X  vel_X  acc_X  laneID_X  localx_Y  localy_Y  vel_Y  \
# 0        23.303   387.964  38.27  -3.96         2    71.841   446.091   0.00
# 1        19.979   418.463  38.33   1.54         2    48.925   444.066   0.00
# 2        26.931   107.493  40.53  -0.79         3    18.327    40.530  38.59
# 3        42.084    31.120   0.00   0.00         1    49.855    60.078   6.47
# 4        71.841   446.091   0.00   0.00         2    37.330   356.416  50.18
# 5        48.925   444.066   0.00   0.00         0    35.364   373.326  40.84
# 6        30.712   134.419  33.50   8.77         3    53.448    55.936   9.59
# 7        71.841   446.091   0.00   0.00         2    40.472   308.769  50.17
# 8        40.711   313.515  45.97 -15.80         3    48.925   444.066   0.00
# 9        15.215    44.153  44.04   0.00         2    38.285   142.789  40.26
# 10       14.494   640.890  51.30   0.16         2   -41.556   797.838  51.71
# ...
